# %% [markdown]
# # run DeepCTR DeepFM on SageMaker

# %%
#environment settings
import json
import time
import boto3
import os
import glob
import pandas as pd

import sagemaker
from sagemaker import get_execution_role

sess = sagemaker.Session()
default_bucket = sess.default_bucket()
client = boto3.client('sagemaker')
s3_client = boto3.client('s3')
aws_region = sess.boto_region_name
role = sagemaker.get_execution_role()

# %%
#train.py
# !mkdir code

# %%
# %%writefile code/train.py
import pandas as pd
import tensorflow as tf
import os
import argparse
from sklearn.metrics import log_loss, roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

from deepctr.models import *
from deepctr.feature_column import SparseFeat, DenseFeat, get_feature_names

if __name__ == "__main__":
    parser = argparse.ArgumentParser()

#     parser.add_argument("--learning-rate", type=float, default=0.01)
#     parser.add_argument("--batch-size", type=int, default=128)
#     parser.add_argument("--batch-norm", type=bool, default=False)
#     parser.add_argument("--dnn-hidden-units", type=str, default="128,64,32")
#     parser.add_argument("--dropout-rate", type=float, default=0.0)

#     parser.add_argument("--checkpoint", type=str, default=None)
    parser.add_argument('--model_dir', type=str, default=os.environ.get('SM_MODEL_DIR'))
    parser.add_argument('--train', type=str, default=os.environ.get('SM_CHANNEL_TRAIN'))

    args, _ = parser.parse_known_args()
    
    
    data = pd.read_csv('/opt/ml/input/data/train/criteo_sample.txt')

    sparse_features = ['C' + str(i) for i in range(1, 27)]
    dense_features = ['I' + str(i) for i in range(1, 14)]

    data[sparse_features] = data[sparse_features].fillna('-1', )
    data[dense_features] = data[dense_features].fillna(0, )
    target = ['label']

    # 1.Label Encoding for sparse features,and do simple Transformation for dense features
    for feat in sparse_features:
        lbe = LabelEncoder()
        data[feat] = lbe.fit_transform(data[feat])
    mms = MinMaxScaler(feature_range=(0, 1))
    data[dense_features] = mms.fit_transform(data[dense_features])

    # 2.count #unique features for each sparse field,and record dense feature field name

    fixlen_feature_columns = [SparseFeat(feat, vocabulary_size=data[feat].max() + 1, embedding_dim=4)
                              for i, feat in enumerate(sparse_features)] + [DenseFeat(feat, 1, )
                                                                            for feat in dense_features]

    dnn_feature_columns = fixlen_feature_columns
    linear_feature_columns = fixlen_feature_columns

    feature_names = get_feature_names(linear_feature_columns + dnn_feature_columns)

    # 3.generate input data for model

    train, test = train_test_split(data, test_size=0.2, random_state=2020)
    train_model_input = {name: train[name] for name in feature_names}
    test_model_input = {name: test[name] for name in feature_names}

    # 4.Define Model,train,predict and evaluate
    model = DeepFM(linear_feature_columns, dnn_feature_columns, task='binary')
    model.compile("adam", "binary_crossentropy",
                  metrics=['binary_crossentropy'], )

    history = model.fit(train_model_input, train[target].values,
                        batch_size=256, epochs=10, verbose=2, validation_split=0.2, )
    model.summary()
    model.save('/opt/ml/model/deepctr-deepfm')
    pred_ans = model.predict(test_model_input, batch_size=256)
    print("test LogLoss", round(log_loss(test[target].values, pred_ans), 4))
    print("test AUC", round(roc_auc_score(test[target].values, pred_ans), 4))
# Out:
# Writing code/train.py

# %%
# %%writefile code/requirements.txt
# pandas
# deepctr
# sklearn
# Out:
# Writing code/requirements.txt

# %%
from sagemaker.tensorflow import TensorFlow

model_name = 'deepctr'
model_output_path =  f"s3://{default_bucket}/deepctr"

tf_estmator = TensorFlow(
    entry_point="train.py",
    source_dir="code",
    role=role,
    input_mode="File",
    instance_count=1,
    instance_type= "ml.c5.4xlarge",
    volume_size=250,
    output_path=model_output_path,
    disable_profiler=True,
    framework_version="2.3",
    py_version='py37',
    keep_alive_period_in_seconds=1800, # warm pool
)



channels= {"train": f's3://{default_bucket}/datasets/deepctr/'}

tf_estmator.fit(inputs=channels,
                job_name=model_name+time.strftime("%Y%m%d%H%M%S", time.localtime())
               )
# Out:
# INFO:sagemaker.image_uris:image_uri is not presented, retrieving image_uri based on instance_type, framework etc.
# INFO:sagemaker:Creating training-job with name: deepctr20230109164620
# 2023-01-09 16:46:21 Starting - Starting the training job...
# 2023-01-09 16:46:36 Starting - Preparing the instances for training......
# 2023-01-09 16:47:51 Downloading - Downloading input data
# 2023-01-09 16:47:51 Training - Downloading the training image...
# 2023-01-09 16:47:56 Training - Training image download completed. Training in progress..2023-01-09 16:48:21.808081: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2023-01-09 16:48:21.808221: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# 2023-01-09 16:48:21.833953: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2023-01-09 16:48:22,925 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# 2023-01-09 16:48:22,933 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2023-01-09 16:48:23,124 sagemaker-training-toolkit INFO     Installing dependencies from requirements.txt:
# /usr/local/bin/python3.7 -m pip install -r requirements.txt
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/site-packages (from -r requirements.txt (line 1)) (1.1.0)
# Collecting deepctr
#   Downloading deepctr-0.9.3-py3-none-any.whl (141 kB)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/site-packages (from -r requirements.txt (line 3)) (0.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/site-packages (from pandas->-r requirements.txt (line 1)) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/site-packages (from pandas->-r requirements.txt (line 1)) (2021.1)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/site-packages (from pandas->-r requirements.txt (line 1)) (1.18.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/site-packages (from deepctr->-r requirements.txt (line 2)) (2.24.0)
# Requirement already satisfied: h5py==2.10.0 in /usr/local/lib/python3.7/site-packages (from deepctr->-r requirements.txt (line 2)) (2.10.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/site-packages (from sklearn->-r requirements.txt (line 3)) (0.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/site-packages (from requests->deepctr->-r requirements.txt (line 2)) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/site-packages (from requests->deepctr->-r requirements.txt (line 2)) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/site-packages (from requests->deepctr->-r requirements.txt (line 2)) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/site-packages (from requests->deepctr->-r requirements.txt (line 2)) (3.0.4)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.7/site-packages (from scikit-learn->sklearn->-r requirements.txt (line 3)) (1.5.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/site-packages (from scikit-learn->sklearn->-r requirements.txt (line 3)) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/site-packages (from scikit-learn->sklearn->-r requirements.txt (line 3)) (1.0.1)
# Installing collected packages: deepctr
# Successfully installed deepctr-0.9.3
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# WARNING: You are using pip version 21.1.2; however, version 22.3.1 is available.
# You should consider upgrading via the '/usr/local/bin/python3.7 -m pip install --upgrade pip' command.
# 2023-01-09 16:48:24,146 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2023-01-09 16:48:24,161 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2023-01-09 16:48:24,175 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2023-01-09 16:48:24,184 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "model_dir": "s3://sagemaker-us-east-1-432088571089/deepctr/deepctr20230109164620/model"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "deepctr20230109164620",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-432088571089/deepctr20230109164620/source/sourcedir.tar.gz",
#     "module_name": "train",
#     "network_interface_name": "eth0",
#     "num_cpus": 16,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.c5.4xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.c5.4xlarge",
#                 "hosts": [
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"model_dir":"s3://sagemaker-us-east-1-432088571089/deepctr/deepctr20230109164620/model"}
# SM_USER_ENTRY_POINT=train.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.c5.4xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.c5.4xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=16
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-432088571089/deepctr20230109164620/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1"],"hyperparameters":{"model_dir":"s3://sagemaker-us-east-1-432088571089/deepctr/deepctr20230109164620/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"deepctr20230109164620","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-432088571089/deepctr20230109164620/source/sourcedir.tar.gz","module_name":"train","network_interface_name":"eth0","num_cpus":16,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.c5.4xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.c5.4xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"train.py"}
# SM_USER_ARGS=["--model_dir","s3://sagemaker-us-east-1-432088571089/deepctr/deepctr20230109164620/model"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_MODEL_DIR=s3://sagemaker-us-east-1-432088571089/deepctr/deepctr20230109164620/model
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python37.zip:/usr/local/lib/python3.7:/usr/local/lib/python3.7/lib-dynload:/usr/local/lib/python3.7/site-packages
# Invoking script with the following command:
# /usr/local/bin/python3.7 train.py --model_dir s3://sagemaker-us-east-1-432088571089/deepctr/deepctr20230109164620/model
# [2023-01-09 16:48:26.367 ip-10-0-124-7.ec2.internal:57 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2023-01-09 16:48:26.544 ip-10-0-124-7.ec2.internal:57 INFO profiler_config_parser.py:102] Unable to find config at /opt/ml/input/config/profilerconfig.json. Profiler is disabled.
# [2023-01-09 16:48:27.364 ip-10-0-124-7.ec2.internal:57 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2023-01-09 16:48:27.364 ip-10-0-124-7.ec2.internal:57 INFO hook.py:201] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2023-01-09 16:48:27.365 ip-10-0-124-7.ec2.internal:57 INFO hook.py:255] Saving to /opt/ml/output/tensors
# [2023-01-09 16:48:27.365 ip-10-0-124-7.ec2.internal:57 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2023-01-09 16:48:27.365 ip-10-0-124-7.ec2.internal:57 INFO hook.py:425] Monitoring the collections: losses, sm_metrics, metrics
# [2023-01-09 16:48:27.379 ip-10-0-124-7.ec2.internal:57 INFO hook.py:425] Monitoring the collections: losses, sm_metrics, metrics
# Epoch 1/10
# 1/1 - 2s - loss: 0.7358 - binary_crossentropy: 0.7358 - batch: 0.0000e+00 - val_loss: 0.7470 - val_binary_crossentropy: 0.7470 - val_batch: 0.0000e+00
# Epoch 2/10
# 1/1 - 0s - loss: 0.7112 - binary_crossentropy: 0.7112 - val_loss: 0.7308 - val_binary_crossentropy: 0.7308 - batch: 1.0000
# Epoch 3/10
# 1/1 - 0s - loss: 0.6894 - binary_crossentropy: 0.6894 - val_loss: 0.7163 - val_binary_crossentropy: 0.7163 - batch: 2.0000
# Epoch 4/10
# 1/1 - 0s - loss: 0.6696 - binary_crossentropy: 0.6696 - val_loss: 0.7025 - val_binary_crossentropy: 0.7025 - batch: 3.0000
# Epoch 5/10
# 1/1 - 0s - loss: 0.6503 - binary_crossentropy: 0.6503 - val_loss: 0.6889 - val_binary_crossentropy: 0.6889 - batch: 4.0000
# Epoch 6/10
# 1/1 - 0s - loss: 0.6312 - binary_crossentropy: 0.6311 - val_loss: 0.6755 - val_binary_crossentropy: 0.6754 - batch: 5.0000
# Epoch 7/10
# 1/1 - 0s - loss: 0.6119 - binary_crossentropy: 0.6119 - val_loss: 0.6625 - val_binary_crossentropy: 0.6625 - batch: 6.0000
# Epoch 8/10
# 1/1 - 0s - loss: 0.5925 - binary_crossentropy: 0.5925 - val_loss: 0.6502 - val_binary_crossentropy: 0.6502 - batch: 7.0000
# Epoch 9/10
# 1/1 - 0s - loss: 0.5731 - binary_crossentropy: 0.5731 - val_loss: 0.6386 - val_binary_crossentropy: 0.6386 - batch: 8.0000
# Epoch 10/10
# 1/1 - 0s - loss: 0.5536 - binary_crossentropy: 0.5536 - val_loss: 0.6278 - val_binary_crossentropy: 0.6278 - batch: 9.0000
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# C1 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# C2 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# C3 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# C4 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# C5 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# C6 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# C7 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# C8 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# C9 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# C10 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C11 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C12 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C13 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C14 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C15 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C16 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C17 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C18 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C19 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C20 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C21 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C22 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C23 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C24 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C25 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C26 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# I1 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# I2 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# I3 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# I4 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# I5 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# I6 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# I7 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# I8 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# I9 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# I10 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# I11 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# I12 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# I13 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# sparse_emb_C1 (Embedding)       (None, 1, 4)         108         C1[0][0]
# __________________________________________________________________________________________________
# sparse_emb_C2 (Embedding)       (None, 1, 4)         368         C2[0][0]
# __________________________________________________________________________________________________
# sparse_emb_C3 (Embedding)       (None, 1, 4)         688         C3[0][0]
# __________________________________________________________________________________________________
# sparse_emb_C4 (Embedding)       (None, 1, 4)         628         C4[0][0]
# __________________________________________________________________________________________________
# sparse_emb_C5 (Embedding)       (None, 1, 4)         48          C5[0][0]
# __________________________________________________________________________________________________
# sparse_emb_C6 (Embedding)       (None, 1, 4)         28          C6[0][0]
# __________________________________________________________________________________________________
# sparse_emb_C7 (Embedding)       (None, 1, 4)         732         C7[0][0]
# __________________________________________________________________________________________________
# sparse_emb_C8 (Embedding)       (None, 1, 4)         76          C8[0][0]
# __________________________________________________________________________________________________
# sparse_emb_C9 (Embedding)       (None, 1, 4)         8           C9[0][0]
# __________________________________________________________________________________________________
# sparse_emb_C10 (Embedding)      (None, 1, 4)         568         C10[0][0]
# __________________________________________________________________________________________________
# sparse_emb_C11 (Embedding)      (None, 1, 4)         692         C11[0][0]
# __________________________________________________________________________________________________
# sparse_emb_C12 (Embedding)      (None, 1, 4)         680         C12[0][0]
# __________________________________________________________________________________________________
# sparse_emb_C13 (Embedding)      (None, 1, 4)         664         C13[0][0]
# __________________________________________________________________________________________________
# sparse_emb_C14 (Embedding)      (None, 1, 4)         56          C14[0][0]
# __________________________________________________________________________________________________
# sparse_emb_C15 (Embedding)      (None, 1, 4)         680         C15[0][0]
# __________________________________________________________________________________________________
# sparse_emb_C16 (Embedding)      (None, 1, 4)         672         C16[0][0]
# __________________________________________________________________________________________________
# sparse_emb_C17 (Embedding)      (None, 1, 4)         36          C17[0][0]
# __________________________________________________________________________________________________
# sparse_emb_C18 (Embedding)      (None, 1, 4)         508         C18[0][0]
# __________________________________________________________________________________________________
# sparse_emb_C19 (Embedding)      (None, 1, 4)         176         C19[0][0]
# __________________________________________________________________________________________________
# sparse_emb_C20 (Embedding)      (None, 1, 4)         16          C20[0][0]
# __________________________________________________________________________________________________
# sparse_emb_C21 (Embedding)      (None, 1, 4)         676         C21[0][0]
# __________________________________________________________________________________________________
# sparse_emb_C22 (Embedding)      (None, 1, 4)         24          C22[0][0]
# __________________________________________________________________________________________________
# sparse_emb_C23 (Embedding)      (None, 1, 4)         40          C23[0][0]
# __________________________________________________________________________________________________
# sparse_emb_C24 (Embedding)      (None, 1, 4)         500         C24[0][0]
# __________________________________________________________________________________________________
# sparse_emb_C25 (Embedding)      (None, 1, 4)         80          C25[0][0]
# __________________________________________________________________________________________________
# sparse_emb_C26 (Embedding)      (None, 1, 4)         360         C26[0][0]
# __________________________________________________________________________________________________
# concat_3 (Concat)               (None, 1, 104)       0           sparse_emb_C1[0][0]
#                                                                  sparse_emb_C2[0][0]
#                                                                  sparse_emb_C3[0][0]
#                                                                  sparse_emb_C4[0][0]
#                                                                  sparse_emb_C5[0][0]
#                                                                  sparse_emb_C6[0][0]
#                                                                  sparse_emb_C7[0][0]
#                                                                  sparse_emb_C8[0][0]
#                                                                  sparse_emb_C9[0][0]
#                                                                  sparse_emb_C10[0][0]
#                                                                  sparse_emb_C11[0][0]
#                                                                  sparse_emb_C12[0][0]
#                                                                  sparse_emb_C13[0][0]
#                                                                  sparse_emb_C14[0][0]
#                                                                  sparse_emb_C15[0][0]
#                                                                  sparse_emb_C16[0][0]
#                                                                  sparse_emb_C17[0][0]
#                                                                  sparse_emb_C18[0][0]
#                                                                  sparse_emb_C19[0][0]
#                                                                  sparse_emb_C20[0][0]
#                                                                  sparse_emb_C21[0][0]
#                                                                  sparse_emb_C22[0][0]
#                                                                  sparse_emb_C23[0][0]
#                                                                  sparse_emb_C24[0][0]
#                                                                  sparse_emb_C25[0][0]
#                                                                  sparse_emb_C26[0][0]
# __________________________________________________________________________________________________
# concat_4 (Concat)               (None, 13)           0           I1[0][0]
#                                                                  I2[0][0]
#                                                                  I3[0][0]
#                                                                  I4[0][0]
#                                                                  I5[0][0]
#                                                                  I6[0][0]
#                                                                  I7[0][0]
#                                                                  I8[0][0]
#                                                                  I9[0][0]
#                                                                  I10[0][0]
#                                                                  I11[0][0]
#                                                                  I12[0][0]
#                                                                  I13[0][0]
# __________________________________________________________________________________________________
# linear0sparse_emb_C1 (Embedding (None, 1, 1)         27          C1[0][0]
# __________________________________________________________________________________________________
# linear0sparse_emb_C2 (Embedding (None, 1, 1)         92          C2[0][0]
# __________________________________________________________________________________________________
# linear0sparse_emb_C3 (Embedding (None, 1, 1)         172         C3[0][0]
# __________________________________________________________________________________________________
# linear0sparse_emb_C4 (Embedding (None, 1, 1)         157         C4[0][0]
# __________________________________________________________________________________________________
# linear0sparse_emb_C5 (Embedding (None, 1, 1)         12          C5[0][0]
# __________________________________________________________________________________________________
# linear0sparse_emb_C6 (Embedding (None, 1, 1)         7           C6[0][0]
# __________________________________________________________________________________________________
# linear0sparse_emb_C7 (Embedding (None, 1, 1)         183         C7[0][0]
# __________________________________________________________________________________________________
# linear0sparse_emb_C8 (Embedding (None, 1, 1)         19          C8[0][0]
# __________________________________________________________________________________________________
# linear0sparse_emb_C9 (Embedding (None, 1, 1)         2           C9[0][0]
# __________________________________________________________________________________________________
# linear0sparse_emb_C10 (Embeddin (None, 1, 1)         142         C10[0][0]
# __________________________________________________________________________________________________
# linear0sparse_emb_C11 (Embeddin (None, 1, 1)         173         C11[0][0]
# __________________________________________________________________________________________________
# linear0sparse_emb_C12 (Embeddin (None, 1, 1)         170         C12[0][0]
# __________________________________________________________________________________________________
# linear0sparse_emb_C13 (Embeddin (None, 1, 1)         166         C13[0][0]
# __________________________________________________________________________________________________
# linear0sparse_emb_C14 (Embeddin (None, 1, 1)         14          C14[0][0]
# __________________________________________________________________________________________________
# linear0sparse_emb_C15 (Embeddin (None, 1, 1)         170         C15[0][0]
# __________________________________________________________________________________________________
# linear0sparse_emb_C16 (Embeddin (None, 1, 1)         168         C16[0][0]
# __________________________________________________________________________________________________
# linear0sparse_emb_C17 (Embeddin (None, 1, 1)         9           C17[0][0]
# __________________________________________________________________________________________________
# linear0sparse_emb_C18 (Embeddin (None, 1, 1)         127         C18[0][0]
# __________________________________________________________________________________________________
# linear0sparse_emb_C19 (Embeddin (None, 1, 1)         44          C19[0][0]
# __________________________________________________________________________________________________
# linear0sparse_emb_C20 (Embeddin (None, 1, 1)         4           C20[0][0]
# __________________________________________________________________________________________________
# linear0sparse_emb_C21 (Embeddin (None, 1, 1)         169         C21[0][0]
# __________________________________________________________________________________________________
# linear0sparse_emb_C22 (Embeddin (None, 1, 1)         6           C22[0][0]
# __________________________________________________________________________________________________
# linear0sparse_emb_C23 (Embeddin (None, 1, 1)         10          C23[0][0]
# __________________________________________________________________________________________________
# linear0sparse_emb_C24 (Embeddin (None, 1, 1)         125         C24[0][0]
# __________________________________________________________________________________________________
# linear0sparse_emb_C25 (Embeddin (None, 1, 1)         20          C25[0][0]
# __________________________________________________________________________________________________
# linear0sparse_emb_C26 (Embeddin (None, 1, 1)         90          C26[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 104)          0           concat_3[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 13)           0           concat_4[0][0]
# __________________________________________________________________________________________________
# concat (Concat)                 (None, 1, 26)        0           linear0sparse_emb_C1[0][0]
#                                                                  linear0sparse_emb_C2[0][0]
#                                                                  linear0sparse_emb_C3[0][0]
#                                                                  linear0sparse_emb_C4[0][0]
#                                                                  linear0sparse_emb_C5[0][0]
#                                                                  linear0sparse_emb_C6[0][0]
#                                                                  linear0sparse_emb_C7[0][0]
#                                                                  linear0sparse_emb_C8[0][0]
#                                                                  linear0sparse_emb_C9[0][0]
#                                                                  linear0sparse_emb_C10[0][0]
#                                                                  linear0sparse_emb_C11[0][0]
#                                                                  linear0sparse_emb_C12[0][0]
#                                                                  linear0sparse_emb_C13[0][0]
#                                                                  linear0sparse_emb_C14[0][0]
#                                                                  linear0sparse_emb_C15[0][0]
#                                                                  linear0sparse_emb_C16[0][0]
#                                                                  linear0sparse_emb_C17[0][0]
#                                                                  linear0sparse_emb_C18[0][0]
#                                                                  linear0sparse_emb_C19[0][0]
#                                                                  linear0sparse_emb_C20[0][0]
#                                                                  linear0sparse_emb_C21[0][0]
#                                                                  linear0sparse_emb_C22[0][0]
#                                                                  linear0sparse_emb_C23[0][0]
#                                                                  linear0sparse_emb_C24[0][0]
#                                                                  linear0sparse_emb_C25[0][0]
#                                                                  linear0sparse_emb_C26[0][0]
# __________________________________________________________________________________________________
# concat_1 (Concat)               (None, 13)           0           I1[0][0]
#                                                                  I2[0][0]
#                                                                  I3[0][0]
#                                                                  I4[0][0]
#                                                                  I5[0][0]
#                                                                  I6[0][0]
#                                                                  I7[0][0]
#                                                                  I8[0][0]
#                                                                  I9[0][0]
#                                                                  I10[0][0]
#                                                                  I11[0][0]
#                                                                  I12[0][0]
#                                                                  I13[0][0]
# __________________________________________________________________________________________________
# concat_5 (Concat)               (None, 117)          0           flatten[0][0]
#                                                                  flatten_1[0][0]
# __________________________________________________________________________________________________
# linear (Linear)                 (None, 1)            13          concat[0][0]
#                                                                  concat_1[0][0]
# __________________________________________________________________________________________________
# concat_2 (Concat)               (None, 26, 4)        0           sparse_emb_C1[0][0]
#                                                                  sparse_emb_C2[0][0]
#                                                                  sparse_emb_C3[0][0]
#                                                                  sparse_emb_C4[0][0]
#                                                                  sparse_emb_C5[0][0]
#                                                                  sparse_emb_C6[0][0]
#                                                                  sparse_emb_C7[0][0]
#                                                                  sparse_emb_C8[0][0]
#                                                                  sparse_emb_C9[0][0]
#                                                                  sparse_emb_C10[0][0]
#                                                                  sparse_emb_C11[0][0]
#                                                                  sparse_emb_C12[0][0]
#                                                                  sparse_emb_C13[0][0]
#                                                                  sparse_emb_C14[0][0]
#                                                                  sparse_emb_C15[0][0]
#                                                                  sparse_emb_C16[0][0]
#                                                                  sparse_emb_C17[0][0]
#                                                                  sparse_emb_C18[0][0]
#                                                                  sparse_emb_C19[0][0]
#                                                                  sparse_emb_C20[0][0]
#                                                                  sparse_emb_C21[0][0]
#                                                                  sparse_emb_C22[0][0]
#                                                                  sparse_emb_C23[0][0]
#                                                                  sparse_emb_C24[0][0]
#                                                                  sparse_emb_C25[0][0]
#                                                                  sparse_emb_C26[0][0]
# __________________________________________________________________________________________________
# dnn (DNN)                       (None, 64)           71360       concat_5[0][0]
# __________________________________________________________________________________________________
# no_mask (NoMask)                (None, 1)            0           linear[0][0]
# __________________________________________________________________________________________________
# fm (FM)                         (None, 1)            0           concat_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            64          dnn[0][0]
# __________________________________________________________________________________________________
# private__add (_Add)             (None, 1)            0           no_mask[0][0]
#                                                                  fm[0][0]
#                                                                  dense[0][0]
# __________________________________________________________________________________________________
# prediction_layer (PredictionLay (None, 1)            1           private__add[0][0]
# ==================================================================================================
# Total params: 82,828
# Trainable params: 82,828
# Non-trainable params: 0
# __________________________________________________________________________________________________
#
# 2023-01-09 16:48:47 Uploading - Uploading generated training modeltest LogLoss 0.5816
# test AUC 0.5806
# 2023-01-09 16:48:24.610187: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2023-01-09 16:48:24.610323: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# 2023-01-09 16:48:24.635718: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/indexed_slices.py:433: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# 2023-01-09 16:48:39.317777: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: /opt/ml/model/deepctr-deepfm/assets
# INFO:tensorflow:Assets written to: /opt/ml/model/deepctr-deepfm/assets
# 2023-01-09 16:48:45,770 sagemaker_tensorflow_container.training WARNING  Your model will NOT be servable with SageMaker TensorFlow Serving containers. The SavedModel bundle is under directory "deepctr-deepfm", not a numeric name.
# 2023-01-09 16:48:45,770 sagemaker-training-toolkit INFO     Reporting training SUCCESS
#
# 2023-01-09 16:48:58 Completed - Instances not retained as a result of warmpool resource limits being exceeded
# Training seconds: 87
# Billable seconds: 87
